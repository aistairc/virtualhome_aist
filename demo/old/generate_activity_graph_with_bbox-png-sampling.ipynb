# %% [markdown]
# This is a script for simulating arbitrary activity and export its results.

# %%
# %matplotlib notebook
import IPython.display
from utils_demo import *
from sys import platform
import sys
from PIL import Image
import matplotlib.pyplot as plt
import json
import rdflib
import glob
import os
import re
import copy
import time
import random
from timeout_decorator import timeout, TimeoutError

sys.path.append('../simulation')
sys.path.append('../dataset_utils/')

import numpy as np
import random
import cv2
import add_preconds
import evolving_graph.check_programs as check_programs
import evolving_graph.utils as utils

from unity_simulator.comm_unity import UnityCommunication

# %%
comm = UnityCommunication(timeout_wait=45)

# %% [markdown]
# Select scene number.
# Please see https://github.com/xavierpuigf/virtualhome/tree/master/simulation#environment .
#
# If you want to use the existing activity data provided by VirtualHome, you can load the dataset.
# Please see the below link for getting the dataset. (Note that there are many errors in the dataset.)
# https://github.com/xavierpuigf/virtualhome#dataset

# %%
scene = 5
scene_graph = "TrimmedTestScene" + str(scene) + "_graph"
executable_program_path = "../../VirtualHome2KG/dataset/programs_processed_precond_nograb_morepreconds/executable_programs/" + scene_graph + "/*/*.txt"
executable_program_list = []
for file_path in glob.glob(executable_program_path):
    executable_program_list.append(file_path.replace("../../VirtualHome2KG/dataset/programs_processed_precond_nograb_morepreconds/executable_programs/" + scene_graph + "/", ""))

# %% [markdown]
# The HomeOntology is used for randomly selecting an activity.
# Load HomeOntology as RDF graph.
# If you do not select an activity randomly, you do not have to use the HomeOntology.

# %%
rdf_g = rdflib.Graph()
rdf_g.parse("../ontology/vh2kg_ontology.ttl", format="ttl")
# Out:
# <Graph identifier=Nf6415fe82ffa4308bc02188d71349b29 (<class 'rdflib.graph.Graph'>)>

# %%
def get_activity_from_ontology(activity_type):
    results = []
    qres = rdf_g.query(
    """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX : <http://www.owl-ontologies.com/VirtualHome.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
select ?activity where { 
    # ?activity rdfs:subClassOf :%s .
 } 
       """ % activity_type)

    result = ""
    for row in qres:
        activity = "".join(row).replace("http://www.owl-ontologies.com/VirtualHome.owl#","")
        arr = activity.split("_")
        arr[0] = arr[0].capitalize()
        activity = " ".join(arr)
        result = activity
        results.append(result)
    return results

# %%
def generate_list_of_steps(file_path):
    file = open(file_path, "r", encoding="utf-8")
    i = 0
    list_of_steps = []
    program_name = ""
    description = ""
    char= "<char0>"
    while True:
        line = file.readline()
        if line:
            line = line.replace("\n","")
            if i==0:
                program_name = line
            elif i==1:
                description = line
            elif line.startswith("["):
                list_of_steps.append(line)
            else:
                pass
            i+=1
        else:
            break
    return program_name, description, list_of_steps

# %%
def get_activity_program(category):
    #unexecutable = ["Take shower", "Take shoes off", "Wash teeth", "Wash face", "Dust", "Clean toilet", "Clean room", "Scrubbing living room tile floor is once week activity for me", "Clean mirror", "Play games", "Play on laptop", "Read on sofa"]
    unexecutable = []
    executable = []
    activities = get_activity_from_ontology(category)
    for activity_name in activities:
        if activity_name in unexecutable:
            continue
        results = [program for program in program_list if program["name"] == activity_name]
        if len(results) == 0:
            print("Nothing: " + activity_name)
        else:
            print("Success: " + activity_name)
            executable.append({"activity_name": activity_name, "results": results})
    return executable

# %%
data_path = "../../VirtualHome2KG/dataset/programs_processed_precond_nograb_morepreconds/withoutconds/*/*.txt"
program_list = []
for file_path in glob.glob(data_path):
    file_name = file_path.replace("../../VirtualHome2KG/dataset/programs_processed_precond_nograb_morepreconds/withoutconds/", "")
    if file_name in executable_program_list:
        program_name, description, list_of_steps = generate_list_of_steps(file_path)
        program_list.append({
            "file_name":file_name,
            "name": program_name,
            "description": description,
            "list_of_steps": list_of_steps
        })

# %%
executable_activity_list = []
executable_activity_dic = {}
for activity_class in ["BedTimeSleep", "EatingDrinking", "FoodPreparation", "GettingReady", "HouseArrangement", "HouseCleaning", "HygieneStyling", "Leisure", "Other", "PhysicalActivity", "SocialInteraction", "Work"]:
    executable_activity_dic[activity_class] = get_activity_program(activity_class)
#     executable_activity_list.extend(get_activity_program(activity_class))
# Out:
# Success: Take nap
# Nothing: Wake me up
# Success: Sleep
# Nothing: Put them to sleep
# Success: Go to sleep
# Nothing: Go to bed
# Nothing: Read them bedtime story
# Nothing: Get ready for bed
# Success: Put alarm clock in bedroom
# Nothing: Bed time
# Success: Have snack
# Nothing: Eat dessert
# Nothing: Eat meals
# Nothing: Eat dinner
# Nothing: Have ice coffee
# Success: Get something to drink
# Nothing: Have dinner
# Nothing: Dining
# Nothing: Eat on fancy china
# Nothing: Eat family meals
# Success: Eat cereal
# Nothing: Eat while watching tv
# Nothing: Eat breaksfast
# Success: Drink
# Success: Eat
# Nothing: Dance for table as we eat
# Nothing: Eat donuts
# Nothing: Eat ice cream
# Success: Eat cheese
# Success: Eat snacks and drink tea
# Success: Prepare pot of boiling water
# Nothing: Make toast
# Nothing: Fix sandwich
# Nothing: Breakfast
# Nothing: Make drink
# Nothing: Make cereal
# Nothing: Make  cookies
# Nothing: Prepare sandwitch
# Nothing: Make tomato sauce
# Success: Fix snack
# Nothing: Make peanut butter sandwhich
# Nothing: Fix sandwhich
# Nothing: Squeeze lemon
# Nothing: Bake
# Nothing: Slice apple
# Nothing: Make peanut butter sandwich
# Nothing: Chop vegetables
# Success: Cook some food
# Nothing: Make ice in ice trays for freezer
# Nothing: Make eggs
# Nothing: Cut steak
# Success: Cut bread
# Nothing: Make jello
# Nothing: Prepare dinner
# Nothing: Make tea
# Nothing: Brew coffee
# Nothing: Eat breakfast
# Nothing: Prepare breakfast
# Nothing: Fix bowl of cereal
# Success: Toast bread
# Nothing: Peel potatoes
# Nothing: Make banana bread
# Nothing: Defrost chicken
# Success: Make coffee
# Nothing: Peel kiwi
# Nothing: Prepare sandwich
# Nothing: Make sandwitch
# Success: Make popcorn
# Nothing: Make iced coffee
# Nothing: Make sandwich
# Nothing: Keep an eye on stove as something is cooking
# Success: Get ready for school
# Nothing: Get ready for day
# Nothing: Get ready for work
# Success: Get ready to leave
# Nothing: Take off outerwear
# Nothing: Fluff pillow
# Nothing: Pick up dirty dishes
# Success: Arrange furniture
# Nothing: Put mail in mail organizer
# Nothing: Replace toothpaste
# Nothing: Collect napkin rings
# Nothing: Change toothbrush
# Nothing: Arrange folders
# Success: Decorate it
# Nothing: Change light
# Nothing: Do laundry
# Nothing: Rotate stock in refrigerator
# Nothing: Unload dishwasher
# Nothing: Change sheets on bed
# Nothing: Load dishwasher
# Nothing: Hold coats and umbrellas
# Nothing: Care for houseplants
# Nothing: Arrange sofa
# Success: Put shoes in shoe rack
# Nothing: Pick toys
# Success: Wash dishes by hand
# Nothing: Make kids bed
# Nothing: Put down decoration
# Nothing: Straighten pictures on wall
# Success: Light candles
# Nothing: Turn night light on
# Success: Put new books in shelves
# Nothing: Put dishes away
# Success: Sort laundry
# Success: Unload various items from pockets and place them in bowl on table
# Success: Wash dishes with dishwasher
# Nothing: Sort clothing and care for it
# Success: Place centerpiece
# Nothing: Polish your shoes
# Nothing: Put groceries in fridge
# Nothing: Hang pictures
# Nothing: Decorate
# Success: Put away clean clothes
# Nothing: Organize cabinet
# Nothing: Organize panrty
# Nothing: Place table
# Success: Straighten paintings on wall
# Nothing: Added meat to freezer
# Nothing: Make childs bed
# Nothing: Put washed clothes in almirah
# Nothing: Change lightbulb
# Nothing: Rearrange photo frames
# Nothing: Straighten magazines
# Nothing: Wash and clean all crystal in china cabinet
# Nothing: Clear table
# Nothing: Bring leftovers in kitchen
# Nothing: Empty dishwasher and fill dishwasher
# Nothing: Water plants
# Nothing: Put slippers in closet
# Nothing: Put toys away
# Nothing: Change curtains
# Success: Make bed
# Nothing: Clean glasses
# Success: Put away groceries
# Nothing: Change bedding
# Nothing: Iron shirt
# Nothing: Put dvds on shelves
# Nothing: Hang up poster
# Nothing: Organize desk
# Nothing: Fold laundry
# Nothing: Make up bed for guest on couch
# Success: Change toilet paper roll
# Nothing: Arrange shoes
# Nothing: Push all chairs in
# Success: Turn off light
# Nothing: Put mail away
# Success: Change sheets and pillow cases
# Nothing: Put away dishes
# Nothing: Change shower curtain
# Nothing: Polish teas pot
# Success: Set up buffet area
# Nothing: Do dishes
# Nothing: Lay tablecloth
# Nothing: Close shower curtain
# Success: Set up table
# Nothing: Place bathmat
# Success: Wash dishes
# Success: Clean dishes
# Nothing: Bring dirty plate to sink
# Nothing: Pick up dIshes
# Success: Take dishes out of dishwasher
# Success: Re arrange office
# Nothing: Arrange bookshelf
# Success: Wash clothes
# Success: Paint ceiling
# Success: Clean toilet
# Nothing: Mop
# Nothing: Scrubbing living room tile floor is once week activity for me
# Success: Clean sink
# Success: Pick up cat hair
# Success: Clean mirror
# Success: De-wrinkle sheet
# Nothing: Steam mop floor
# Nothing: Sweep floor
# Nothing: Clean bathroom
# Nothing: Wipe down sink
# Nothing: Clean fridge
# Success: Mop floor
# Success: Oil dining room
# Nothing: Fluff pillows
# Nothing: Scrub toilet
# Success: Organize closet
# Success: Shred receipts
# Nothing: Flush toilet
# Nothing: Wash dirty dishes
# Success: Dust
# Success: Vacuum
# Nothing: Clean kitchen
# Nothing: Sort and fold laundry
# Nothing: Clean large jacuzzi tub
# Nothing: Sweep entrance hall
# Nothing: Vacuum carpet
# Nothing: Wipe room down with lysol
# Success: Clean
# Success: Sweep hallway please
# Nothing: Polishing floor
# Success: Wash sink
# Nothing: Sweep and wipe table off with rag
# Nothing: Pull hair out of drain
# Success: Clean floor
# Nothing: Wash table
# Nothing: Polish table
# Nothing: Clean screen
# Success: Clean room
# Nothing: Wash monitor
# Nothing: Do nails
# Success: Put on coat
# Nothing: Use restroom
# Nothing: Check self in mirror
# Nothing: Shampoo hair
# Nothing: Give children bath
# Success: Put on coat and shoes
# Nothing: Scrub face
# Nothing: Blow dry hair
# Nothing: Dry hair
# Nothing: Go pee
# Nothing: Take off coat
# Success: Apply lotion
# Success: Check appearance in mirror
# Nothing: Tale off shoes
# Success: Wash face
# Nothing: Dress up and pretend
# Nothing: Put shoes and coats
# Success: Take off shoes
# Nothing: Use bathroom
# Nothing: Put up coat
# Nothing: Comb hair
# Nothing: Curled hair
# Nothing: Scrub bottom of feet
# Nothing: Paint nails
# Success: Take shower
# Success: Brush teeth
# Success: Use toilet
# Success: Deficate
# Nothing: Face washing
# Nothing: Give me bath
# Nothing: Getting dressed
# Nothing: Bathe
# Nothing: Give your child bath
# Nothing: Do facial
# Success: Put on your shoes
# Nothing: Cut toenails
# Nothing: Brush hair
# Success: Wash teeth
# Success: Hand washing
# Nothing: Hair dressing
# Success: Go to toilet
# Nothing: Wipe feet
# Nothing: Pee
# Nothing: Cut your hair
# Nothing: Wash hair
# Success: Take jacket off
# Success: Change clothes
# Nothing: Put on glasses
# Nothing: Style hair
# Success: Get dressed
# Nothing: Broom
# Nothing: Take shoes off
# Success: Wash hands
# Nothing: Put on foundation
# Nothing: Toilet
# Nothing: Take bath
# Nothing: Take off shoes and hang up coat
# Nothing: Shave
# Nothing: Go to bathroom
# Success: Browse internet
# Nothing: Movie
# Nothing: Turn off tv
# Success: Read newspaper
# Nothing: In living room i eat dinner
# Nothing: Turn on tv with remote
# Nothing: Play piano
# Nothing: Change tv channels
# Nothing: Browse computer
# Success: Relax
# Nothing: Read on sofa
# Success: Read book
# Nothing: Juggling
# Nothing: Sing song
# Nothing: Play guitar
# Success: Read magazine
# Nothing: Eat while watching tv
# Nothing: Tabletop game
# Nothing: Dance
# Success: Playing video game
# Success: Listen to music
# Nothing: Read yourself to sleep
# Nothing: Practice violin
# Nothing: Watch tv
# Nothing: Turn on tv
# Nothing: Practice own singing
# Success: Watch youtube
# Success: Read news
# Nothing: Sing karaoke
# Success: Play on laptop
# Nothing: Playtime lunch with dolls
# Success: Social media  checks
# Success: Watch movie
# Nothing: Play
# Nothing: Turn on radio
# Nothing: Surf net
# Success: Watch  horror  movie
# Success: Play musical chairs
# Success: Surf internet
# Nothing: Play with barbies
# Success: Play games
# Success: Relax on sofa
# Nothing: Wash back
# Nothing: Get drink
# Nothing: Teach them to make their bed
# Success: Shop
# Nothing: Take coat
# Nothing: Try yourself off
# Nothing: Lay down on floor and say im rug
# Success: Write book
# Success: Grab things
# Nothing: Write in your diary
# Success: Turn light off
# Nothing: Serve cookies
# Success: Settle in
# Nothing: Set up tv
# Nothing: Hang keys
# Success: Hang with friends
# Nothing: Read text message
# Nothing: Give milk to cat
# Success: Find dictionary
# Success: Hang up car keys
# Success: Compute
# Nothing: Do an art project
# Success: Read
# Nothing: Sort mail
# Success: Leave home
# Nothing: Serve food
# Nothing: Pack lunch
# Nothing: Push in dining room chair
# Success: Put umbrella away
# Nothing: Shut off alarm
# Success: Turn on light
# Nothing: Pick up dishes
# Success: Put away toys
# Nothing: Hair
# Nothing: Plug in nightlight
# Nothing: Close dresser drawer
# Nothing: Keep cats inside while door is open
# Nothing: Serve breakfast
# Success: Getting  dresses
# Nothing: Color
# Nothing: Come in and leave home
# Nothing: Sit quietly
# Nothing: Celebrate birthday with nice meal
# Nothing: Put up towel
# Success: Put down bags
# Nothing: Answer phone
# Success: Look out window
# Nothing: Hang car keys
# Success: Look at mirror
# Nothing: Straighten bookshelf
# Nothing: Laugh
# Nothing: Throw away paper
# Nothing: Feed daughter
# Nothing: Sit
# Nothing: Pick up all trash
# Success: Use laptop
# Nothing: Put away blankets
# Nothing: Tummy time
# Success: Enjoy view out window
# Nothing: Build lego house
# Nothing: Take of outerwear
# Nothing: Look in refrigerator
# Nothing: Pick up obvious trash
# Nothing: Shoe removal
# Nothing: Pull up carpet
# Nothing: Tidy
# Nothing: Put up feet
# Success: Cutting
# Nothing: Turn on lights
# Nothing: Celebrate
# Nothing: Shredding
# Success: Walk through
# Nothing: Gaze out window
# Success: Draft home
# Nothing: Put clothes away
# Success: Raise blinds
# Success: Open window
# Nothing: Get in way of guests trying to leave
# Success: Hang up jacket
# Success: Start computer
# Nothing: String green beans
# Success: Restock
# Nothing: Wipe off shoes
# Nothing: Feed dog
# Nothing: Pick up
# Nothing: Organize
# Nothing: Wait
# Nothing: Pop zit
# Nothing: Put up jacket
# Nothing: Sew button
# Nothing: Return from store
# Nothing: Set out some snacks for toddler
# Success: Wipe down counter
# Success: Let baby learn how to walk
# Nothing: Make tutu
# Nothing: Put up decoration
# Nothing: Get toilet paper
# Nothing: Organize files
# Nothing: Sew
# Nothing: Get glass of milk
# Nothing: Put away keys
# Success: Grab some juice
# Nothing: Close curtains
# Success: Come home
# Nothing: Recycle items
# Success: Open front door
# Nothing: Get glass of water
# Nothing: Carry groceries to kitchen
# Nothing: Card
# Nothing: Change tv channel
# Nothing: Help with quiz shows
# Success: Pick up spare change on dresser
# Nothing: Clean eggs from our chickens
# Nothing: Pet dog
# Nothing: Wash dining table
# Nothing: Pour cup of coffee
# Nothing: Turn on computer
# Nothing: Open bathroom window
# Nothing: Praying
# Nothing: Do free-style dance routine
# Nothing: Hang out
# Nothing: Get some water
# Success: Open door
# Nothing: Turking
# Nothing: Throw shoes
# Success: Put away shoes
# Nothing: Serve meal
# Nothing: Play with toys
# Success: Enter home
# Success: Spread table with appropriate supplies
# Nothing: Wipe down baseboards please
# Nothing: Bring me red cookbook
# Nothing: Visit with friends while engaging in games
# Nothing: Annoy your dog
# Nothing: Bring food
# Nothing: Push in desk chair
# Nothing: Hide
# Nothing: Get out dish
# Success: Switch on lamp
# Nothing: Break table
# Nothing: Put on purse put keys and lucky charms in pockets leave home
# Nothing: Light candle
# Nothing: Fix broken toys
# Nothing: Draw picture
# Success: Pick up toys
# Nothing: Help organize files
# Success: Add paper to printer
# Nothing: Pretend tea
# Nothing: Return phone calls
# Nothing: Put out flowers
# Nothing: Lock door
# Nothing: Fan magazines on coffee table
# Nothing: Admire art
# Success: Pick up phone
# Nothing: Whine
# Nothing: Write
# Nothing: Put away clothes
# Nothing: Sit in chair
# Success: Receive credit card
# Success: Throw away newspaper
# Nothing: De wrinkle sheet
# Success: Feed me
# Nothing: Write story
# Success: Open curtains
# Nothing: Set mail on table
# Nothing: Shut front door
# Nothing: Replace towel
# Nothing: Walk to room
# Success: Close door
# Nothing: Watch fly
# Success: Put away jackets
# Success: Put in chair
# Success: Rain welcome
# Nothing: Designing crafts with family
# Success: Look at painting
# Success: Dry soap bottles
# Nothing: Make place cards
# Nothing: Workout
# Nothing: Exercise
# Nothing: Physical therapy
# Nothing: Stretch
# Nothing: Do yoga
# Nothing: Yoga
# Success: Entertain
# Nothing: Text friend
# Nothing: Tuck kids in bed
# Nothing: Open door and great guests
# Nothing: Hang with friend
# Nothing: Call family member with skype application
# Nothing: Have tea party
# Nothing: Say goodbye
# Nothing: Story reading time
# Nothing: Let bay learn how to walk
# Nothing: Make phone call
# Nothing: Talk on phone
# Success: Text friends while sitting on couch
# Nothing: Massage
# Nothing: Serve hors doeurves to entering guests at cocktail party
# Nothing: Talk with guest
# Nothing: Speaking on headset in skype or some form of voip for business call
# Nothing: Help kids with homework
# Nothing: Visit
# Nothing: Dance with kids
# Nothing: Family meetings
# Nothing: Getting in way of guest trying to leave
# Nothing: Have quality family time
# Success: Keep cats out of room
# Nothing: Greet people
# Nothing: Wave at people walking by through window
# Success: Wake kids up
# Nothing: Call mother
# Success: Read to child
# Nothing: Answer door
# Nothing: Talk with your child about their day
# Nothing: Thanksgiving
# Nothing: Play fetch with dog
# Nothing: Give children bath
# Nothing: Meeting
# Nothing: Say goodbye to guests leaving
# Nothing: Spend family time playing games
# Nothing: Visit neighbors
# Nothing: Talk to kids
# Success: Greet guests
# Nothing: Have party
# Success: Pet cat
# Nothing: Tell jokes
# Nothing: Ignore people
# Nothing: Have conversation with boyfriend
# Nothing: Trick or treat
# Nothing: Be able to talk to me about tv show im watching
# Nothing: Call client
# Nothing: Talk with friends
# Nothing: Print documents
# Nothing: Mail signed letter to customer
# Success: Check email
# Nothing: Write research paper
# Nothing: Do work on computer
# Nothing: Complete homework
# Nothing: Prepare letter for mailing
# Nothing: Sent email
# Nothing: Write thank you notes
# Success: Use computer
# Success: Research
# Success: Print out document
# Success: Surf web for money legitimate making opportunities
# Nothing: Speaking on headset in skype or some form of voip for business call
# Nothing: Check homework
# Success: Study
# Nothing: Manage documents
# Nothing: Grading papers
# Nothing: Send  email
# Success: Write report
# Nothing: Manage emails
# Nothing: Fax forms to doctor
# Nothing: Do work
# Success: Complete surveys on amazon turk
# Nothing: Complete school work
# Success: Type up document
# Success: Write an email
# Success: File documents
# Nothing: Write letter
# Success: Do homework
# Nothing: File expense reports
# Nothing: Organise paperwork
# Success: Pay bills
# Nothing: Make several copies on printer
# Nothing: Update address book
# Success: Homework
# Nothing: Computer work
# Nothing: Do taxes
# Nothing: Read paper
# Nothing: Study bible
# Nothing: Write research papers
# Success: Print out papers
# Nothing: Tax filing
# Nothing: Transcribe what i say
# Nothing: Prepare for work
# Nothing: Write school paper
# Success: Browse internet
# Success: Answer emails
# Nothing: Get mail ready
# Nothing: Order office suplies
# Nothing: Organize paperwork

# %%
unsupport_unity = [
    "PutOn",
    "PutOff",
    "Drop",
    "PlugIn",
    "PlugOut",
    "Sleep",
    "Wake"
]

# %%
def check_unsupport_action(script):
    flag = True
    for line in script:
        m = re.search(r'\[.+\]', line)
        action = m.group().replace('[', '')
        action = action.replace(']', '')
        if action in unsupport_unity:
            flag = False
            break
    return flag

# %%
def switchOff(g, class_names):
    for class_name in class_names:
        objects = find_nodes(g, class_name=class_name)
        for obj in objects:
            states = [x for x in obj["states"] if x != "ON"]
            if "OFF" not in states:
                states.append("OFF")
            obj["states"] = states
#             for node in g["nodes"]:
#                 if node["id"] == obj["id"]:
#                     node = obj
        return g

# %%
def export(activity_name, graph_state_list, activity_cnt, time_list, script, object_name_map, out_dir_name):
    state_cnt = 0
    for graph_state in graph_state_list:
        state_cnt += 1
        file_path = "graph_state_list_with_bbox_png/" + out_dir_name + "_scene" + str(scene) + "/"  + activity_name + "/" + activity_cnt + "/activityList-graph-state-" + '{0:03d}'.format(state_cnt) + ".json"
        with open(file_path, 'w') as outfile:
            json.dump(graph_state, outfile)

    with open("graph_state_list_with_bbox_png/" + out_dir_name + "_scene" + str(scene) + "/" + activity_name + "/" + activity_cnt + "/activityList-program.txt", 'w') as f:
        for s in script:
            #ここでscriptのobject_nameを置換する処理書く
            for x in object_name_map:
                if x in s:
                    s = s.replace("<" + x  + ">", "<" + object_name_map[x] + ">")
            f.write("%s\n" % s)

    with open("graph_state_list_with_bbox_png/" + out_dir_name + "_scene" + str(scene) + "/" + activity_name + "/" + activity_cnt  + "/program-description.txt", 'w') as f:
        f.write("%s\n" % activity["name"])
        f.write("%s\n" % activity["description"])
        
    time_list = [str(time) for time in time_list]
    duration = "\n".join(time_list)
    with open("graph_state_list_with_bbox_png/" + out_dir_name + "_scene" + str(scene) + "/" + activity_name + "/" + activity_cnt + "/duration.txt", 'w') as f:
        f.write(duration)

# %%
def update_bbox(pre_graph, current_graph):
    try:
        new_graph= copy.deepcopy(current_graph)
        
        for pre_node in pre_graph["nodes"]:
            for new_node in new_graph["nodes"]:
                if new_node["id"] == pre_node["id"]:
                    new_node["bounding_box"] = pre_node["bounding_box"]
           
    except Exception as e:
        print(e)
    
    return new_graph

# %%
def update_states(pre_graph, graph_state, object_id_map):
    try:
        new_graph= copy.deepcopy(pre_graph)
        
        skip = [object_id_map[x] for x in object_id_map]
        for new_node in new_graph["nodes"]:
            new_node_id = new_node["id"]
            if new_node_id in skip:
                continue
            temp_node_id = copy.deepcopy(new_node_id)
            # scriptで使用したobject_idとgraph_stateで反映されたidが異なる場合
            if str(new_node_id) in object_id_map:
                temp_node_id = object_id_map[str(new_node_id)]
            for graph_state_node in graph_state["nodes"]:
                if temp_node_id == graph_state_node["id"]:
                    new_node["states"] = graph_state_node["states"]
                    new_node["properties"] = graph_state_node["states"]
           
    except Exception as e:
        print(e)
    
    return new_graph

# %%
def create_object_id_map(original_script, executed_program, g):
    try:
        object_id_map = {}
        object_name_map = {}
        for original_block_str, executed_block_str in zip(original_script, executed_program):
            original_action, original_obj_names_corr, original_inst_nums_corr = augmentation_utils.parseStrBlock(original_block_str)
            executed_action, executed_obj_names_corr, executed_inst_nums_corr = augmentation_utils.parseStrBlock(executed_block_str)
            
            #object_idのmapを作る
            for original_id, executed_id in zip(original_inst_nums_corr, executed_inst_nums_corr):
                if original_id not in object_id_map:
                    if original_id != executed_id:
                        object_id_map[original_id] = int(executed_id)
            
            #object_nameのmap作る
            for original_obj_name, original_id in zip(original_obj_names_corr, original_inst_nums_corr):
                g_objects = [x for x in g["nodes"] if x["id"] == original_id]
                if len(g_objects) != 0:
                    g_obj = g_objects[0]
                    if original_obj_name != g_obj["class_name"]:
                        object_name_map[original_obj_name] = g_obj["class_name"]
    except Exception as e:
        print(e)
    return object_id_map, object_name_map

# %%
def delete2000(graph_state_list):
    new_graph_state_list = []
    for graph_state in graph_state_list:
        new_nodes = [x for x in graph_state["nodes"] if x["id"] < 2000]
        new_edges = [x for x in graph_state["edges"] if x["from_id"] < 2000 and x["to_id"] < 2000]
        new_graph_state_list.append({"nodes": new_nodes, "edges": new_edges})
    return new_graph_state_list

# %%
@timeout(40)
def time_managed_render_script(instruction, find_solution, image_width, recording, image_height, file_name_prefix, frame_rate, vis_check_object, vis_check_character, out_graph):
    success, message = comm.render_script(script=[instruction],
#                                               processing_time_limit=60,
                                              find_solution=find_solution,
                                              image_width=image_width,
                                              image_height=image_height,  
                                              #skip_animation=False,
                                              recording=True,
#                                               gen_vid=True,
                                              #save_scene_states=True,
                                              file_name_prefix=file_name_prefix,
                                              output_folder="Output/",
                                              frame_rate=frame_rate,
                                              vis_check_object=vis_check_object, 
                                              vis_check_character=vis_check_character, 
                                              out_graph=out_graph
                                             )
    return success, message

# %%
out_dir_name = "test20220719"

for activity_class in executable_activity_dic:
    executable_activity_list = executable_activity_dic[activity_class]
    rand_executable_activity_list = []
    print(activity_class)
    if len(executable_activity_list) >=3:
        rand_executable_activity_list = random.sample(executable_activity_list, 3)
    elif len(executable_activity_list) > 0:
        rand_executable_activity_list = random.sample(executable_activity_list, len(executable_activity_list))
    else:
        continue
#rand_executable_activity_list = random.sample(executable_activity_list, len(executable_activity_list))
    for executable_activity in rand_executable_activity_list:
        activity_list = executable_activity["results"]
        activity_name = executable_activity["activity_name"]
        activity_cnt = 0
        try:
            # if activity_name != "Relax on sofa": 
            #     continue
            os.mkdir("graph_state_list_with_bbox_png/" + out_dir_name + "_scene" + str(scene) + "/" + activity_name)
            for activity in activity_list:
                if activity_cnt > 0:
                    break
                try:
                    new_graph_state_list = []
                    time_list = []
                    comm.reset(scene-1)
                    comm.add_character('chars/Male1')
                    success, g = comm.environment_graph();
                    print(activity["file_name"])
                    script = activity["list_of_steps"]
                    print(script)
                    executable_program = []
                    for x in script:
                        executable_program.append("<char0> " + x)
                    executable_program

                    # check if supported action
                    if check_unsupport_action(script) == False:
                        continue

    #                 #sit
    #                 sit = False
    #                 for s in script:
    #                     if "Sit" in s:
    #                         sit = True
    #                         continue
    #                 if sit:
    #                     continue

                    preconds = add_preconds.get_preconds_script(script).printCondsJSON()

                    print(preconds)
                    print("switch off")
                    g = switchOff(g, ["computer", "tv", "faucet", "television"])

                    g = check_programs.translate_graph_dict_nofile(g)
                    info = check_programs.check_script(script, preconds, graph_path=None, inp_graph_dict=g)
                    message, final_state, graph_state_list, graph_dict, id_mapping, info, helper, executed_script = info
                    # if delete randomly placced objects 
                    graph_state_list = delete2000(graph_state_list)
                    print(message)
                    executed_program = []
                    for x in executed_script:
                        executed_program.append("<char0> " + re.sub("\[\d+\]","",x.__str__()).strip())

                    if message != "Script is executable":
                        continue

                    new_script = []
                    for x in script:
                        new_script.append("<char0> " + x)

                    i = 0

                    object_id_map, object_name_map = create_object_id_map(new_script, executed_program, g)
                    print("object_id_map")
                    print(object_id_map)

                    success, g = comm.environment_graph()
                    g = update_states(g, graph_state_list[i], object_id_map)
                    new_graph_state_list.append(copy.deepcopy(g))

                    for instruction in executed_program:
                        i += 1
                        start = time.time()
    #                     try:
    #                         success, g = time_managed_render_script(instruction,False,480,360,True,activity_name + str(activity_cnt), 15,False,False,False)
    #                     except TimeoutError as e:
    #                         print(e)
    #                         break;
    #                     finally:
    #                         print("掛った時間", time.time() - start)
                        success, message = comm.render_script(script=[instruction],
    #                                               processing_time_limit=60,
                                                  find_solution=False,
                                                  image_width=480,
                                                  image_height=360,  
                                                  #skip_animation=False,
                                                  recording=True,
    #                                               gen_vid=True,
                                                  #save_scene_states=True,
                                                  file_name_prefix=activity_name + str(activity_cnt),
                                                  output_folder="Output/scene" + str(scene),
                                                  frame_rate=15,
                                                  vis_check_object=False, 
                                                  vis_check_character=False, 
                                                  out_graph=False
                                                 )
                        time_list.append(time.time() - start)
                        success, g = comm.environment_graph()
                        print(str(success) + ": " + str(instruction))
                        g = update_states(g, graph_state_list[i], object_id_map)
                        new_graph_state_list.append(copy.deepcopy(g))

                    if os.path.exists("graph_state_list_with_bbox_png/" + out_dir_name + "_scene" + str(scene) + "/" + activity_name + "/" + str(activity_cnt)) == False:
                        os.mkdir("graph_state_list_with_bbox_png/" + out_dir_name + "_scene" + str(scene) + "/" + activity_name + "/" + str(activity_cnt))
                    export(activity_name, new_graph_state_list, str(activity_cnt), time_list, new_script, object_name_map,  out_dir_name)

                    activity_cnt += 1
                except Exception as e:
                    print(e.args)
        except Exception as e:
            print(e.args)
# Out:
# BedTimeSleep
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split11_6.txt
# ['[Walk] <bedroom> (1)', '[Walk] <alarm_clock> (1)', '[Find] <alarm_clock> (1)', '[Grab] <alarm_clock> (1)', '[Find] <dresser> (1)', '[Open] <dresser> (1)', '[PutBack] <alarm_clock> (1) <dresser> (1)', '[SwitchOn] <alarm_clock> (1)']
# ('alarm_clock',)
# results_intentions_march-13-18/file509_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <clothes_pants> (1)', '[Find] <clothes_pants> (1)', '[Find] <clothes_pants> (1)', '[Find] <clothes_pants> (1)', '[PutOff] <clothes_pants> (1)', '[Find] <clothes_shirt> (1)', '[Find] <clothes_shirt> (1)', '[Find] <clothes_shirt> (1)', '[PutOff] <clothes_shirt> (1)', '[Find] <clothes_shirt> (2)', '[Grab] <clothes_shirt> (2)', '[PutOn] <clothes_shirt> (2)', '[Find] <clothes_pants> (2)', '[Grab] <clothes_pants> (2)', '[PutOn] <clothes_pants> (2)', '[Find] <light> (1)', '[SwitchOff] <light> (1)', '[Find] <bed> (1)', '[Lie] <bed> (1)', '[Find] <sheets> (1)', '[Pull] <sheets> (1)', '[Sleep]']
# results_intentions_march-13-18/file597_1.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_intentions_march-13-18/file1027_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_intentions_march-13-18/file144_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <pajamas> (1)', '[Find] <pajamas> (1)', '[Grab] <pajamas> (1)', '[PutOn] <pajamas> (1)', '[Find] <bed> (1)', '[Lie] <bed> (1)']
# results_intentions_march-13-18/file140_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Find] <bed> (1)', '[TurnTo] <bed> (1)', '[LookAt] <bed> (1)', '[Sit] <bed> (1)', '[Sleep]']
# results_intentions_march-13-18/file735_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Find] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_intentions_march-13-18/file244_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_intentions_march-13-18/file181_1.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Find] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_intentions_march-13-18/file736_1.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Find] <bed> (1)', '[Lie] <bed> (1)', '[Find] <comforter> (1)', '[Pull] <comforter> (1)']
# [{'atreach': [['bed', '1'], ['comforter', '1']]}, {'atreach': [['comforter', '1'], ['bed', '1']]}, {'location': [['bed', '1'], ['bedroom', '1']]}, {'location': [['comforter', '1'], ['bedroom', '1']]}, {'free': ['bed', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <bedroom> (281)
# True: <char0> [WALK] <bed> (315)
# True: <char0> [FIND] <bed> (315)
# True: <char0> [LIE] <bed> (315)
# True: <char0> [FIND] <sheets> (1000)
# True: <char0> [PULL] <sheets> (1000)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split1_3.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split80_3.txt
# ['[Walk] <bedroom> (1)', '[Walk] <closet> (1)', '[Find] <closet> (1)', '[Open] <closet> (1)', '[Find] <pajamas> (1)', '[Grab] <pajamas> (1)', '[PutOn] <pajamas> (1)', '[Close] <closet> (1)', '[Walk] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_text_rebuttal_specialparsed_programs_turk_third/split78_4.txt
# ['[Walk] <bedroom> (1)', '[Walk] <closet> (1)', '[Find] <closet> (1)', '[Open] <closet> (1)', '[Find] <pajamas> (1)', '[Grab] <pajamas> (1)', '[Close] <closet> (1)', '[Find] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_text_rebuttal_specialparsed_programs_turk_third/split7_1.txt
# ['[Walk] <bedroom> (1)', '[Walk] <lamp> (1)', '[SwitchOff] <lamp> (1)', '[Walk] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]', '[Sleep]', '[Sleep]']
# results_text_rebuttal_specialparsed_programs_turk_third/split82_2.txt
# ['[Find] <bed> (1)', '[TurnTo] <bed> (1)', '[PointAt] <bed> (1)', '[Wash] <bed> (1)', '[TurnTo] <bed> (1)', '[LookAt] <bed> (1)', '[Touch] <bed> (1)', '[Sit] <bed> (1)']
# [{'free': ['bed', '1']}]
# switch off
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split104_1.txt
# ['[Walk] <living_room> (1)', '[Walk] <television> (1)', '[Find] <television> (1)', '[SwitchOn] <television> (1)', '[Walk] <sofa> (1)', '[Sit] <sofa> (1)', '[TurnTo] <television> (1)', '[Watch] <television> (1)', '[Lie] <sofa> (1)', '[Sleep]']
# results_text_rebuttal_specialparsed_programs_upwork_july/split22_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <bed> (1)', '[Find] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# results_text_rebuttal_specialparsed_programs_upwork_july/split2_6.txt
# ['[Walk] <bedroom> (1)', '[Walk] <pajamas> (1)', '[Find] <pajamas> (1)', '[Grab] <pajamas> (1)', '[PutOn] <pajamas> (1)', '[Walk] <bed> (1)', '[Lie] <bed> (1)', '[Sleep]']
# EatingDrinking
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split29_3.txt
# ['[Walk] <dining_room> (1)', '[Walk] <table> (1)', '[Find] <chair> (1)', '[Pull] <chair> (1)', '[Sit] <chair> (1)', '[Find] <plate> (1)', '[Find] <food_food> (1)', '[Grab] <food_food> (1)', '[PutBack] <food_food> (1) <plate> (1)', '[Eat] <plate> (1)']
# [{'atreach': [['chair', '1'], ['food_food', '1']]}, {'atreach': [['chair', '1'], ['plate', '1']]}, {'atreach': [['chair', '1'], ['table', '1']]}, {'atreach': [['plate', '1'], ['table', '1']]}, {'atreach': [['food_food', '1'], ['table', '1']]}, {'location': [['table', '1'], ['dining_room', '1']]}, {'location': [['chair', '1'], ['dining_room', '1']]}, {'location': [['plate', '1'], ['dining_room', '1']]}, {'location': [['food_food', '1'], ['dining_room', '1']]}, {'free': ['chair', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <dining_room> (56)
# True: <char0> [WALK] <table> (129)
# True: <char0> [FIND] <chair> (152)
# True: <char0> [PULL] <chair> (152)
# True: <char0> [SIT] <chair> (152)
# True: <char0> [FIND] <plate> (1001)
# True: <char0> [FIND] <food_food> (1000)
# True: <char0> [GRAB] <food_food> (1000)
# True: <char0> [PUTBACK] <food_food> (1000) <plate> (1001)
# True: <char0> [EAT] <plate> (1001)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split113_2.txt
# ['[Walk] <kitchen> (1)', '[Walk] <plate> (1)', '[Find] <plate> (1)', '[Grab] <plate> (1)', '[Find] <food_food> (1)', '[Grab] <food_food> (1)', '[PutBack] <food_food> (1) <plate> (1)', '[Walk] <dining_room> (1)', '[Walk] <table> (1)', '[Find] <table> (1)', '[PutBack] <plate> (1) <table> (1)', '[Find] <chair> (1)', '[Sit] <chair> (1)', '[Eat] <plate> (1)']
# [{'atreach': [['chair', '1'], ['table', '1']]}, {'atreach': [['food_food', '1'], ['plate', '1']]}, {'atreach': [['plate', '1'], ['table', '1']]}, {'location': [['plate', '1'], ['kitchen', '1']]}, {'location': [['plate', '1'], ['dining_room', '1']]}, {'location': [['food_food', '1'], ['kitchen', '1']]}, {'location': [['table', '1'], ['dining_room', '1']]}, {'location': [['chair', '1'], ['dining_room', '1']]}, {'free': ['chair', '1']}]
# switch off
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split37_1.txt
# ['[Walk] <dining_room> (1)', '[Walk] <table> (1)', '[Find] <chair> (1)', '[Pull] <chair> (1)', '[Sit] <chair> (1)', '[Find] <food_food> (1)', '[TurnTo] <food_food> (1)', '[LookAt] <food_food> (1)', '[Grab] <food_food> (1)', '[Find] <plate> (1)', '[PutBack] <food_food> (1) <plate> (1)', '[Grab] <food_food> (1)', '[PutObjBack] <food_food> (1)', '[Find] <fork> (1)', '[Grab] <fork> (1)', '[Eat] <plate> (1)']
# [{'atreach': [['chair', '1'], ['food_food', '1']]}, {'atreach': [['chair', '1'], ['fork', '1']]}, {'atreach': [['chair', '1'], ['plate', '1']]}, {'atreach': [['chair', '1'], ['table', '1']]}, {'atreach': [['food_food', '1'], ['table', '1']]}, {'atreach': [['plate', '1'], ['table', '1']]}, {'atreach': [['fork', '1'], ['table', '1']]}, {'location': [['table', '1'], ['dining_room', '1']]}, {'location': [['chair', '1'], ['dining_room', '1']]}, {'location': [['food_food', '1'], ['dining_room', '1']]}, {'location': [['plate', '1'], ['dining_room', '1']]}, {'location': [['fork', '1'], ['dining_room', '1']]}, {'free': ['chair', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <dining_room> (56)
# True: <char0> [WALK] <table> (129)
# True: <char0> [FIND] <chair> (152)
# True: <char0> [PULL] <chair> (152)
# True: <char0> [SIT] <chair> (152)
# True: <char0> [FIND] <food_food> (1001)
# True: <char0> [TURNTO] <food_food> (1001)
# True: <char0> [LOOKAT] <food_food> (1001)
# True: <char0> [GRAB] <food_food> (1001)
# True: <char0> [FIND] <plate> (1002)
# True: <char0> [PUTBACK] <food_food> (1001) <plate> (1002)
# True: <char0> [GRAB] <food_food> (1001)
# True: <char0> [PUTOBJBACK] <food_food> (1001)
# True: <char0> [FIND] <fork> (1000)
# True: <char0> [GRAB] <fork> (1000)
# True: <char0> [EAT] <plate> (1002)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split6_10.txt
# ['[Walk] <kitchen> (1)', '[Walk] <fridge> (1)', '[Find] <fridge> (1)', '[Open] <fridge> (1)', '[Find] <beer> (1)', '[Grab] <beer> (1)', '[Close] <fridge> (1)', '[Walk] <living_room> (1)', '[Walk] <couch> (1)', '[Find] <couch> (1)', '[Sit] <couch> (1)', '[Drink] <beer> (1)']
# [{'atreach': [['beer', '1'], ['fridge', '1']]}, {'location': [['fridge', '1'], ['kitchen', '1']]}, {'location': [['beer', '1'], ['kitchen', '1']]}, {'location': [['beer', '1'], ['living_room', '1']]}, {'location': [['couch', '1'], ['living_room', '1']]}, {'closed': ['fridge', '1']}, {'inside': [['beer', '1'], ['fridge', '1']]}, {'free': ['couch', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <dining_room> (56)
# True: <char0> [WALK] <freezer> (164)
# True: <char0> [FIND] <freezer> (164)
# True: <char0> [OPEN] <freezer> (164)
# True: <char0> [FIND] <beer> (1000)
# True: <char0> [GRAB] <beer> (1000)
# True: <char0> [CLOSE] <freezer> (164)
# True: <char0> [WALK] <home_office> (197)
# True: <char0> [WALK] <couch> (246)
# True: <char0> [FIND] <couch> (246)
# True: <char0> [SIT] <couch> (246)
# True: <char0> [DRINK] <beer> (1000)
# FoodPreparation
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split87_1.txt
# ['[Walk] <kitchen> (1)', '[Walk] <food_food> (1)', '[Find] <food_food> (1)', '[Grab] <food_food> (1)', '[Walk] <microwave> (1)', '[TurnTo] <microwave> (1)', '[Open] <microwave> (1)', '[PutIn] <food_food> (1) <microwave> (1)', '[Close] <microwave> (1)', '[SwitchOn] <microwave> (1)']
# [{'is_off': ['microwave', '1']}, {'plugged': ['microwave', '1']}, {'location': [['food_food', '1'], ['kitchen', '1']]}, {'location': [['microwave', '1'], ['kitchen', '1']]}, {'closed': ['microwave', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <dining_room> (56)
# True: <char0> [WALK] <food_food> (1000)
# True: <char0> [FIND] <food_food> (1000)
# True: <char0> [GRAB] <food_food> (1000)
# True: <char0> [WALK] <microwave> (166)
# True: <char0> [TURNTO] <microwave> (166)
# True: <char0> [OPEN] <microwave> (166)
# True: <char0> [PUTIN] <food_food> (1000) <microwave> (166)
# True: <char0> [CLOSE] <microwave> (166)
# True: <char0> [SWITCHON] <microwave> (166)
# results_text_rebuttal_specialparsed_programs_upwork_july/split14_6.txt
# ['[Walk] <kitchen> (1)', '[Walk] <fridge> (1)', '[Find] <fridge> (1)', '[Open] <fridge> (1)', '[Find] <food_bread> (1)', '[Grab] <food_bread> (1)', '[Close] <fridge> (1)', '[Find] <toaster> (1)', '[PlugIn] <toaster> (1)', '[PutBack] <food_bread> (1) <toaster> (1)', '[SwitchOn] <toaster> (1)']
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split11_5.txt
# ['[Walk] <kitchen> (1)', '[Walk] <fridge> (1)', '[Find] <fridge> (1)', '[Open] <fridge> (1)', '[Find] <food_bread> (1)', '[Grab] <food_bread> (1)', '[Close] <fridge> (1)', '[Walk] <electrical_outlet> (1)', '[Find] <toaster> (1)', '[PlugIn] <toaster> (1)', '[PutBack] <food_bread> (1) <toaster> (1)', '[SwitchOn] <electrical_outlet> (1)', '[TurnTo] <toaster> (1)', '[LookAt] <toaster> (1)', '[SwitchOn] <toaster> (1)']
# GettingReady
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split81_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <closet> (1)', '[Find] <closet> (1)', '[Open] <closet> (1)', '[Find] <shoes> (1)', '[Grab] <shoes> (1)', '[PutOn] <shoes> (1)', '[Find] <clothes_jacket> (1)', '[Grab] <clothes_jacket> (1)', '[PutOn] <clothes_jacket> (1)', '[Close] <closet> (1)', '[Find] <cellphone> (1)', '[Grab] <cellphone> (1)']
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split9_8.txt
# ['[Walk] <entrance_hall> (1)', '[Walk] <shoes> (1)', '[Find] <shoes> (1)', '[Grab] <shoes> (1)', '[PutOn] <shoes> (1)', '[Find] <keys> (1)', '[Grab] <keys> (1)']
# results_text_rebuttal_specialparsed_programs_turk_third/split2_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <closet> (1)', '[Find] <closet> (1)', '[Open] <closet> (1)', '[Find] <clothes_dress> (1)', '[Grab] <clothes_dress> (1)', '[PutOn] <clothes_dress> (1)', '[Find] <shoes> (1)', '[Grab] <shoes> (1)', '[PutOn] <shoes> (1)', '[Find] <purse> (1)', '[Grab] <purse> (1)', '[Close] <closet> (1)', '[Walk] <entrance_hall> (1)']
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split127_2.txt
# ['[Walk] <entrance_hall> (1)', '[Walk] <light> (1)', '[Find] <light> (1)', '[SwitchOn] <light> (1)', '[Find] <clothes_hat> (1)', '[Find] <clothes_hat> (1)', '[PutOff] <clothes_hat> (1)', '[Grab] <clothes_hat> (1)', '[Find] <hanger> (1)', '[Find] <clothes_jacket> (1)', '[PutBack] <clothes_hat> (1) <hanger> (1)', '[Find] <clothes_jacket> (1)', '[PutOff] <clothes_jacket> (1)', '[Find] <shoes> (1)', '[Grab] <clothes_jacket> (1)', '[PutBack] <clothes_jacket> (1) <hanger> (1)', '[Find] <shoes> (1)', '[PutOff] <shoes> (1)', '[Find] <closet> (1)', '[Open] <closet> (1)', '[Grab] <shoes> (1)', '[PutIn] <shoes> (1) <closet> (1)', '[Close] <closet> (1)']
# HouseArrangement
# results_text_rebuttal_specialparsed_programs_turk_robot/split5_2.txt
# ['[Find] <pillow> (1)', '[TurnTo] <pillow> (1)', '[LookAt] <pillow> (1)', '[Grab] <pillow> (1)']
# []
# switch off
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split95_4.txt
# ['[Walk] <home_office> (1)', '[Walk] <desk> (1)', '[Find] <folder> (1)', '[Grab] <folder> (1)', '[Open] <desk> (1)', '[PutBack] <folder> (1) <desk> (1)', '[Find] <folder> (2)', '[Grab] <folder> (2)', '[PutBack] <folder> (2) <desk> (1)', '[Find] <folder> (3)', '[Grab] <folder> (3)', '[PutBack] <folder> (3) <desk> (1)', '[Find] <folder> (4)', '[Grab] <folder> (4)', '[PutBack] <folder> (4) <desk> (1)', '[Find] <folder> (5)', '[Grab] <folder> (5)', '[PutBack] <folder> (5) <desk> (1)']
# [{'atreach': [['folder', '1'], ['desk', '1']]}, {'atreach': [['folder', '2'], ['desk', '1']]}, {'atreach': [['folder', '3'], ['desk', '1']]}, {'atreach': [['folder', '4'], ['desk', '1']]}, {'atreach': [['folder', '5'], ['desk', '1']]}, {'location': [['desk', '1'], ['home_office', '1']]}, {'location': [['folder', '1'], ['home_office', '1']]}, {'location': [['folder', '2'], ['home_office', '1']]}, {'location': [['folder', '3'], ['home_office', '1']]}, {'location': [['folder', '4'], ['home_office', '1']]}, {'location': [['folder', '5'], ['home_office', '1']]}, {'closed': ['desk', '1']}, {'inside': [['folder', '2'], ['desk', '1']]}, {'inside': [['folder', '3'], ['desk', '1']]}, {'inside': [['folder', '4'], ['desk', '1']]}, {'inside': [['folder', '5'], ['desk', '1']]}, {'in': [['folder', '1'], ['desk', '1']]}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <home_office> (197)
# True: <char0> [WALK] <desk> (243)
# True: <char0> [FIND] <folder> (1000)
# True: <char0> [GRAB] <folder> (1000)
# True: <char0> [OPEN] <desk> (243)
# True: <char0> [PUTBACK] <folder> (1000) <desk> (243)
# True: <char0> [FIND] <folder> (1002)
# True: <char0> [GRAB] <folder> (1002)
# True: <char0> [PUTBACK] <folder> (1002) <desk> (243)
# True: <char0> [FIND] <folder> (1001)
# True: <char0> [GRAB] <folder> (1001)
# True: <char0> [PUTBACK] <folder> (1001) <desk> (243)
# True: <char0> [FIND] <folder> (1004)
# True: <char0> [GRAB] <folder> (1004)
# True: <char0> [PUTBACK] <folder> (1004) <desk> (243)
# True: <char0> [FIND] <folder> (1003)
# True: <char0> [GRAB] <folder> (1003)
# True: <char0> [PUTBACK] <folder> (1003) <desk> (243)
# results_text_rebuttal_specialparsed_programs_turk_robot/split37_2.txt
# ['[Find] <soap> (1)', '[TurnTo] <soap> (1)', '[PointAt] <soap> (1)', '[Wash] <soap> (1)', '[TurnTo] <soap> (1)', '[LookAt] <soap> (1)']
# []
# switch off
# ('execute() takes 5 positional arguments but 6 were given',)
# HouseCleaning
# results_intentions_march-13-18/file367_1.txt
# ['[Walk] <bathroom> (1)', '[Walk] <brush> (1)', '[Find] <brush> (1)', '[Grab] <brush> (1)', '[Find] <detergent> (1)', '[Grab] <detergent> (1)', '[Find] <toilet> (1)', '[PutBack] <detergent> (1) <toilet> (1)', '[Find] <toilet> (1)', '[Scrub] <toilet> (1)', '[Rinse] <toilet> (1)', '[Find] <shower> (1)', '[Scrub] <shower> (1)', '[Rinse] <shower> (1)']
# [{'atreach': [['detergent', '1'], ['brush', '1']]}, {'atreach': [['toilet', '1'], ['brush', '1']]}, {'atreach': [['shower', '1'], ['brush', '1']]}, {'location': [['brush', '1'], ['bathroom', '1']]}, {'location': [['detergent', '1'], ['bathroom', '1']]}, {'location': [['toilet', '1'], ['bathroom', '1']]}, {'location': [['shower', '1'], ['bathroom', '1']]}, {'free': ['toilet', '1']}]
# switch off
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split68_3.txt
# ['[Walk] <kitchen> (1)', '[Walk] <rag> (1)', '[Find] <rag> (1)', '[Grab] <rag> (1)', '[Walk] <sink> (1)', '[Find] <faucet> (1)', '[SwitchOn] <faucet> (1)', '[PutBack] <rag> (1) <sink> (1)', '[SwitchOff] <faucet> (1)', '[Grab] <rag> (1)', '[Squeeze] <rag> (1)', '[Walk] <kitchen_counter> (1)', '[Wipe] <kitchen_counter> (1)', '[PutObjBack] <rag> (1)']
# [{'is_off': ['faucet', '1']}, {'atreach': [['faucet', '1'], ['sink', '1']]}, {'atreach': [['rag', '1'], ['sink', '1']]}, {'location': [['rag', '1'], ['kitchen', '1']]}, {'location': [['sink', '1'], ['kitchen', '1']]}, {'location': [['faucet', '1'], ['kitchen', '1']]}, {'location': [['kitchen_counter', '1'], ['kitchen', '1']]}, {'in': [['faucet', '1'], ['sink', '1']]}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <dining_room> (56)
# True: <char0> [WALK] <rag> (1000)
# True: <char0> [FIND] <rag> (1000)
# True: <char0> [GRAB] <rag> (1000)
# True: <char0> [WALK] <sink> (148)
# True: <char0> [FIND] <faucet> (149)
# True: <char0> [SWITCHON] <faucet> (149)
# True: <char0> [PUTBACK] <rag> (1000) <sink> (148)
# True: <char0> [SWITCHOFF] <faucet> (149)
# True: <char0> [GRAB] <rag> (1000)
# True: <char0> [SQUEEZE] <rag> (1000)
# True: <char0> [WALK] <kitchen_counter> (140)
# True: <char0> [WIPE] <kitchen_counter> (140)
# True: <char0> [PUTOBJBACK] <rag> (1000)
# results_text_rebuttal_specialparsed_programs_turk_robot/split26_3.txt
# ['[Walk] <bedroom> (1)', '[Walk] <closet> (1)', '[Open] <closet> (1)', '[Find] <clothes_pants> (1)', '[Grab] <clothes_pants> (1)', '[Pull] <clothes_pants> (1)', '[PutIn] <clothes_pants> (1) <closet> (1)', '[Find] <clothes_pants> (2)', '[Grab] <clothes_pants> (2)', '[Pull] <clothes_pants> (2)', '[PutIn] <clothes_pants> (2) <closet> (1)', '[Find] <clothes_shirt> (1)', '[Grab] <clothes_shirt> (1)', '[Push] <clothes_shirt> (1)', '[PutIn] <clothes_shirt> (1) <closet> (1)', '[Find] <clothes_shirt> (2)', '[Grab] <clothes_shirt> (2)', '[Push] <clothes_shirt> (2)', '[PutIn] <clothes_shirt> (2) <closet> (1)', '[Find] <clothes_shirt> (3)', '[Grab] <clothes_shirt> (3)', '[Close] <closet> (1)', '[Walk] <basket_for_clothes> (1)', '[PutBack] <clothes_shirt> (3) <basket_for_clothes> (1)']
# [{'atreach': [['clothes_pants', '1'], ['closet', '1']]}, {'atreach': [['clothes_pants', '2'], ['closet', '1']]}, {'atreach': [['clothes_shirt', '1'], ['closet', '1']]}, {'atreach': [['clothes_shirt', '2'], ['closet', '1']]}, {'atreach': [['clothes_shirt', '3'], ['closet', '1']]}, {'location': [['closet', '1'], ['bedroom', '1']]}, {'location': [['clothes_pants', '1'], ['bedroom', '1']]}, {'location': [['clothes_pants', '2'], ['bedroom', '1']]}, {'location': [['clothes_shirt', '1'], ['bedroom', '1']]}, {'location': [['clothes_shirt', '2'], ['bedroom', '1']]}, {'location': [['clothes_shirt', '3'], ['bedroom', '1']]}, {'location': [['basket_for_clothes', '1'], ['bedroom', '1']]}, {'closed': ['closet', '1']}, {'inside': [['clothes_pants', '1'], ['closet', '1']]}, {'inside': [['clothes_pants', '2'], ['closet', '1']]}, {'inside': [['clothes_shirt', '1'], ['closet', '1']]}, {'inside': [['clothes_shirt', '2'], ['closet', '1']]}, {'inside': [['clothes_shirt', '3'], ['closet', '1']]}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <bedroom> (281)
# True: <char0> [WALK] <dresser> (305)
# True: <char0> [OPEN] <dresser> (305)
# True: <char0> [FIND] <clothes_pants> (1002)
# True: <char0> [GRAB] <clothes_pants> (1002)
# True: <char0> [PULL] <clothes_pants> (1002)
# True: <char0> [PUTIN] <clothes_pants> (1002) <dresser> (305)
# True: <char0> [FIND] <clothes_pants> (1005)
# True: <char0> [GRAB] <clothes_pants> (1005)
# True: <char0> [PULL] <clothes_pants> (1005)
# True: <char0> [PUTIN] <clothes_pants> (1005) <dresser> (305)
# True: <char0> [FIND] <clothes_shirt> (1001)
# True: <char0> [GRAB] <clothes_shirt> (1001)
# True: <char0> [PUSH] <clothes_shirt> (1001)
# True: <char0> [PUTIN] <clothes_shirt> (1001) <dresser> (305)
# True: <char0> [FIND] <clothes_shirt> (1000)
# True: <char0> [GRAB] <clothes_shirt> (1000)
# True: <char0> [PUSH] <clothes_shirt> (1000)
# True: <char0> [PUTIN] <clothes_shirt> (1000) <dresser> (305)
# True: <char0> [FIND] <clothes_shirt> (1003)
# True: <char0> [GRAB] <clothes_shirt> (1003)
# True: <char0> [CLOSE] <dresser> (305)
# True: <char0> [WALK] <basket_for_clothes> (1004)
# True: <char0> [PUTBACK] <clothes_shirt> (1003) <basket_for_clothes> (1004)
# HygieneStyling
# results_text_rebuttal_specialparsed_programs_turk_third/split59_1.txt
# ['[Find] <toilet> (1)', '[Wash] <toilet> (1)', '[TurnTo] <toilet> (1)', '[LookAt] <toilet> (1)']
# [{'free': ['toilet', '1']}]
# switch off
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split109_3.txt
# ['[Walk] <bathroom> (1)', '[Walk] <toilet> (1)', '[Find] <clothes_pants> (1)', '[Find] <clothes_pants> (1)', '[PutOff] <clothes_pants> (1)', '[Sit] <toilet> (1)', '[Find] <toilet_paper> (1)', '[Grab] <toilet_paper> (1)', '[Find] <woman> (1)', '[Wipe] <woman> (1)']
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split26_3.txt
# ['[Walk] <entrance_hall> (1)', '[Walk] <shoes> (1)', '[Find] <shoes> (1)', '[Find] <shoes> (1)', '[PutOff] <shoes> (1)', '[Grab] <shoes> (1)', '[Find] <carpet> (1)', '[PutBack] <shoes> (1) <carpet> (1)']
# Leisure
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split8_3.txt
# ['[Walk] <living_room> (1)', '[Walk] <laptop> (1)', '[Find] <laptop> (1)', '[Grab] <laptop> (1)', '[Find] <couch> (1)', '[Sit] <couch> (1)', '[SwitchOn] <laptop> (1)', '[TurnTo] <laptop> (1)', '[LookAt] <laptop> (1)', '[Find] <keyboard> (1)', '[Type] <keyboard> (1)']
# [{'is_off': ['laptop', '1']}, {'plugged': ['laptop', '1']}, {'atreach': [['couch', '1'], ['keyboard', '1']]}, {'atreach': [['couch', '1'], ['laptop', '1']]}, {'atreach': [['keyboard', '1'], ['laptop', '1']]}, {'location': [['laptop', '1'], ['living_room', '1']]}, {'location': [['couch', '1'], ['living_room', '1']]}, {'location': [['keyboard', '1'], ['living_room', '1']]}, {'free': ['couch', '1']}]
# switch off
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split1_6.txt
# ['[Walk] <living_room> (1)', '[Walk] <radio> (1)', '[Find] <radio> (1)', '[Find] <electrical_outlet> (1)', '[TurnTo] <electrical_outlet> (1)', '[PlugIn] <radio> (1)', '[SwitchOn] <electrical_outlet> (1)', '[SwitchOn] <radio> (1)']
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split26_2.txt
# ['[Walk] <living_room> (1)', '[Walk] <coffee_table> (1)', '[Find] <novel> (1)', '[Grab] <novel> (1)', '[Find] <sofa> (1)', '[Sit] <sofa> (1)', '[Find] <bookmark> (1)', '[Read] <novel> (1)']
# [{'atreach': [['sofa', '1'], ['coffee_table', '1']]}, {'atreach': [['sofa', '1'], ['bookmark', '1']]}, {'atreach': [['novel', '1'], ['coffee_table', '1']]}, {'atreach': [['bookmark', '1'], ['coffee_table', '1']]}, {'location': [['coffee_table', '1'], ['living_room', '1']]}, {'location': [['novel', '1'], ['living_room', '1']]}, {'location': [['sofa', '1'], ['living_room', '1']]}, {'location': [['bookmark', '1'], ['living_room', '1']]}, {'in': [['novel', '1'], ['coffee_table', '1']]}, {'free': ['sofa', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <home_office> (197)
# True: <char0> [WALK] <coffee_table> (1000)
# True: <char0> [FIND] <novel> (1001)
# True: <char0> [GRAB] <novel> (1001)
# True: <char0> [FIND] <couch> (246)
# True: <char0> [SIT] <couch> (246)
# True: <char0> [FIND] <bookmark> (1002)
# True: <char0> [READ] <novel> (1001)
# Other
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split3_4.txt
# ['[Walk] <bathroom> (1)', '[Walk] <mirror> (1)', '[Find] <mirror> (1)', '[TurnTo] <mirror> (1)', '[LookAt] <mirror> (1)']
# [{'location': [['mirror', '1'], ['bathroom', '1']]}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <bathroom> (11)
# True: <char0> [WALK] <mirror> (1000)
# True: <char0> [FIND] <mirror> (1000)
# True: <char0> [TURNTO] <mirror> (1000)
# True: <char0> [LOOKAT] <mirror> (1000)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split66_3.txt
# ['[Walk] <kitchen> (1)', '[Walk] <cupboard> (1)', '[Find] <cupboard> (1)', '[Open] <cupboard> (1)', '[Find] <cutting_board> (1)', '[Grab] <cutting_board> (1)', '[Find] <chef_knife> (1)', '[Grab] <chef_knife> (1)', '[Close] <cupboard> (1)', '[Find] <table> (1)', '[PutBack] <cutting_board> (1) <table> (1)', '[PutBack] <chef_knife> (1) <table> (1)', '[Find] <fridge> (1)', '[Open] <fridge> (1)', '[Find] <food_vegetable> (1)', '[Grab] <food_vegetable> (1)', '[Find] <food_vegetable> (2)', '[Grab] <food_vegetable> (2)', '[Close] <fridge> (1)', '[PutBack] <food_vegetable> (1) <cutting_board> (1)', '[PutBack] <food_vegetable> (2) <cutting_board> (1)', '[Grab] <chef_knife> (1)', '[Cut] <food_vegetable> (1)', '[Cut] <food_vegetable> (2)', '[PutObjBack] <chef_knife> (1)']
# [{'atreach': [['cutting_board', '1'], ['cupboard', '1']]}, {'atreach': [['chef_knife', '1'], ['cupboard', '1']]}, {'atreach': [['table', '1'], ['cupboard', '1']]}, {'atreach': [['fridge', '1'], ['cupboard', '1']]}, {'atreach': [['food_vegetable', '1'], ['cupboard', '1']]}, {'atreach': [['food_vegetable', '2'], ['cupboard', '1']]}, {'location': [['cupboard', '1'], ['kitchen', '1']]}, {'location': [['cutting_board', '1'], ['kitchen', '1']]}, {'location': [['chef_knife', '1'], ['kitchen', '1']]}, {'location': [['table', '1'], ['kitchen', '1']]}, {'location': [['fridge', '1'], ['kitchen', '1']]}, {'location': [['food_vegetable', '1'], ['kitchen', '1']]}, {'location': [['food_vegetable', '2'], ['kitchen', '1']]}, {'closed': ['cupboard', '1']}, {'closed': ['fridge', '1']}, {'inside': [['cutting_board', '1'], ['cupboard', '1']]}, {'inside': [['chef_knife', '1'], ['cupboard', '1']]}, {'inside': [['food_vegetable', '1'], ['fridge', '1']]}, {'inside': [['food_vegetable', '2'], ['fridge', '1']]}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <dining_room> (56)
# True: <char0> [WALK] <cupboard> (1001)
# True: <char0> [FIND] <cupboard> (1001)
# True: <char0> [OPEN] <cupboard> (1001)
# True: <char0> [FIND] <cutting_board> (1002)
# True: <char0> [GRAB] <cutting_board> (1002)
# True: <char0> [FIND] <chef_knife> (1004)
# True: <char0> [GRAB] <chef_knife> (1004)
# True: <char0> [CLOSE] <cupboard> (1001)
# True: <char0> [FIND] <table> (129)
# True: <char0> [PUTBACK] <cutting_board> (1002) <table> (129)
# True: <char0> [PUTBACK] <chef_knife> (1004) <table> (129)
# True: <char0> [FIND] <freezer> (164)
# True: <char0> [OPEN] <freezer> (164)
# True: <char0> [FIND] <food_vegetable> (1000)
# True: <char0> [GRAB] <food_vegetable> (1000)
# True: <char0> [FIND] <food_vegetable> (1003)
# True: <char0> [GRAB] <food_vegetable> (1003)
# True: <char0> [CLOSE] <freezer> (164)
# True: <char0> [PUTBACK] <food_vegetable> (1000) <cutting_board> (1002)
# True: <char0> [PUTBACK] <food_vegetable> (1003) <cutting_board> (1002)
# True: <char0> [GRAB] <chef_knife> (1004)
# True: <char0> [CUT] <food_vegetable> (1000)
# True: <char0> [CUT] <food_vegetable> (1003)
# True: <char0> [PUTOBJBACK] <chef_knife> (1004)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split8_7.txt
# ['[Walk] <dining_room> (1)', '[Walk] <chair> (1)', '[Find] <chair> (1)', '[Pull] <chair> (1)', '[Sit] <chair> (1)']
# [{'location': [['chair', '1'], ['dining_room', '1']]}, {'free': ['chair', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <dining_room> (56)
# True: <char0> [WALK] <chair> (152)
# True: <char0> [FIND] <chair> (152)
# True: <char0> [PULL] <chair> (152)
# True: <char0> [SIT] <chair> (152)
# PhysicalActivity
# SocialInteraction
# results_text_rebuttal_specialparsed_programs_turk_third/split117_1.txt
# ['[Walk] <living_room> (1)', '[Walk] <sofa> (1)', '[Find] <sofa> (1)', '[Walk] <sofa> (1)', '[Sit] <sofa> (1)', '[Find] <man> (1)', '[Greet] <man> (1)']
# [{'atreach': [['sofa', '1'], ['man', '1']]}, {'atreach': [['man', '1'], ['sofa', '1']]}, {'location': [['sofa', '1'], ['living_room', '1']]}, {'location': [['man', '1'], ['living_room', '1']]}, {'free': ['sofa', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <home_office> (197)
# True: <char0> [WALK] <couch> (246)
# True: <char0> [FIND] <couch> (246)
# True: <char0> [WALK] <couch> (246)
# True: <char0> [SIT] <couch> (246)
# True: <char0> [FIND] <man> (1000)
# True: <char0> [GREET] <man> (1000)
# results_text_rebuttal_specialparsed_programs_turk_third/split14_2.txt
# ['[Walk] <entrance_hall> (1)', '[Walk] <woman> (1)', '[Find] <woman> (1)', '[Greet] <woman> (1)', '[Find] <woman> (2)', '[Greet] <woman> (2)', '[Find] <man> (1)', '[Greet] <man> (1)', '[Find] <man> (2)', '[Greet] <man> (2)']
# [{'atreach': [['woman', '2'], ['woman', '1']]}, {'atreach': [['man', '1'], ['woman', '1']]}, {'atreach': [['man', '2'], ['woman', '1']]}, {'location': [['woman', '1'], ['entrance_hall', '1']]}, {'location': [['woman', '2'], ['entrance_hall', '1']]}, {'location': [['man', '1'], ['entrance_hall', '1']]}, {'location': [['man', '2'], ['entrance_hall', '1']]}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <home_office> (197)
# True: <char0> [WALK] <woman> (1002)
# True: <char0> [FIND] <woman> (1002)
# True: <char0> [GREET] <woman> (1002)
# True: <char0> [FIND] <woman> (1001)
# True: <char0> [GREET] <woman> (1001)
# True: <char0> [FIND] <man> (1000)
# True: <char0> [GREET] <man> (1000)
# True: <char0> [FIND] <man> (1003)
# True: <char0> [GREET] <man> (1003)
# results_text_rebuttal_specialparsed_programs_turk_robot/split6_2.txt
# ['[Walk] <bedroom> (1)', '[Walk] <child> (1)', '[Find] <child> (1)', '[Greet] <child> (1)', '[Walk] <cabinet> (1)', '[Open] <cabinet> (1)', '[Find] <book> (1)', '[Grab] <book> (1)', '[Walk] <chair> (1)', '[Pull] <chair> (1)', '[Sit] <chair> (1)', '[TurnTo] <book> (1)', '[LookAt] <book> (1)', '[TurnTo] <book> (1)', '[PointAt] <book> (1)', '[TurnTo] <book> (1)', '[PointAt] <book> (1)', '[Read] <book> (1)', '[Read] <book> (1)', '[Read] <book> (1)']
# [{'atreach': [['book', '1'], ['cabinet', '1']]}, {'location': [['child', '1'], ['bedroom', '1']]}, {'location': [['cabinet', '1'], ['bedroom', '1']]}, {'location': [['book', '1'], ['bedroom', '1']]}, {'location': [['chair', '1'], ['bedroom', '1']]}, {'closed': ['cabinet', '1']}, {'inside': [['book', '1'], ['cabinet', '1']]}, {'free': ['chair', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <bedroom> (281)
# True: <char0> [WALK] <child> (1000)
# True: <char0> [FIND] <child> (1000)
# True: <char0> [GREET] <child> (1000)
# True: <char0> [WALK] <filing_cabinet> (314)
# True: <char0> [OPEN] <filing_cabinet> (314)
# True: <char0> [FIND] <novel> (1001)
# True: <char0> [GRAB] <novel> (1001)
# True: <char0> [WALK] <chair> (304)
# True: <char0> [PULL] <chair> (304)
# True: <char0> [SIT] <chair> (304)
# True: <char0> [TURNTO] <novel> (1001)
# True: <char0> [LOOKAT] <novel> (1001)
# True: <char0> [TURNTO] <novel> (1001)
# True: <char0> [POINTAT] <novel> (1001)
# True: <char0> [TURNTO] <novel> (1001)
# True: <char0> [POINTAT] <novel> (1001)
# True: <char0> [READ] <novel> (1001)
# True: <char0> [READ] <novel> (1001)
# True: <char0> [READ] <novel> (1001)
# Work
# results_text_rebuttal_specialparsed_programs_turk_third/split19_1.txt
# ['[Walk] <home_office> (1)', '[Walk] <desk> (1)', '[Find] <computer> (1)', '[SwitchOn] <computer> (1)', '[Find] <chair> (1)', '[Pull] <chair> (1)', '[Sit] <chair> (1)', '[TurnTo] <computer> (1)', '[LookAt] <computer> (1)', '[Find] <mouse> (1)', '[Grab] <mouse> (1)', '[Pull] <mouse> (1)', '[Touch] <mouse> (1)', '[TurnTo] <computer> (1)', '[LookAt] <computer> (1)', '[Find] <keyboard> (1)', '[Type] <keyboard> (1)', '[TurnTo] <computer> (1)', '[LookAt] <computer> (1)', '[Type] <keyboard> (1)', '[TurnTo] <computer> (1)', '[LookAt] <computer> (1)', '[Type] <keyboard> (1)', '[Touch] <mouse> (1)', '[Find] <printer> (1)', '[SwitchOn] <printer> (1)', '[SwitchOff] <printer> (1)', '[SwitchOff] <computer> (1)']
# [{'is_off': ['computer', '1']}, {'is_off': ['printer', '1']}, {'plugged': ['printer', '1']}, {'atreach': [['chair', '1'], ['printer', '1']]}, {'atreach': [['chair', '1'], ['keyboard', '1']]}, {'atreach': [['chair', '1'], ['mouse', '1']]}, {'atreach': [['chair', '1'], ['desk', '1']]}, {'atreach': [['chair', '1'], ['computer', '1']]}, {'atreach': [['computer', '1'], ['desk', '1']]}, {'atreach': [['mouse', '1'], ['desk', '1']]}, {'atreach': [['keyboard', '1'], ['desk', '1']]}, {'atreach': [['printer', '1'], ['desk', '1']]}, {'location': [['desk', '1'], ['home_office', '1']]}, {'location': [['computer', '1'], ['home_office', '1']]}, {'location': [['chair', '1'], ['home_office', '1']]}, {'location': [['mouse', '1'], ['home_office', '1']]}, {'location': [['keyboard', '1'], ['home_office', '1']]}, {'location': [['printer', '1'], ['home_office', '1']]}, {'in': [['computer', '1'], ['desk', '1']]}, {'free': ['chair', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <home_office> (197)
# True: <char0> [WALK] <desk> (243)
# True: <char0> [FIND] <computer> (273)
# True: <char0> [SWITCHON] <computer> (273)
# True: <char0> [FIND] <chair> (244)
# True: <char0> [PULL] <chair> (244)
# True: <char0> [SIT] <chair> (244)
# True: <char0> [TURNTO] <computer> (273)
# True: <char0> [LOOKAT] <computer> (273)
# True: <char0> [FIND] <mouse> (277)
# True: <char0> [GRAB] <mouse> (277)
# True: <char0> [PULL] <mouse> (277)
# True: <char0> [TOUCH] <mouse> (277)
# True: <char0> [TURNTO] <computer> (273)
# True: <char0> [LOOKAT] <computer> (273)
# True: <char0> [FIND] <keyboard> (275)
# True: <char0> [TYPE] <keyboard> (275)
# True: <char0> [TURNTO] <computer> (273)
# True: <char0> [LOOKAT] <computer> (273)
# True: <char0> [TYPE] <keyboard> (275)
# True: <char0> [TURNTO] <computer> (273)
# True: <char0> [LOOKAT] <computer> (273)
# True: <char0> [TYPE] <keyboard> (275)
# True: <char0> [TOUCH] <mouse> (277)
# True: <char0> [FIND] <fax_machine> (1000)
# True: <char0> [SWITCHON] <fax_machine> (1000)
# True: <char0> [SWITCHOFF] <fax_machine> (1000)
# True: <char0> [SWITCHOFF] <computer> (273)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split140_2.txt
# ['[Walk] <home_office> (1)', '[Walk] <chair> (1)', '[Find] <chair> (1)', '[Sit] <chair> (1)', '[Find] <computer> (1)', '[SwitchOn] <computer> (1)', '[TurnTo] <computer> (1)', '[LookAt] <computer> (1)', '[Find] <keyboard> (1)', '[Type] <keyboard> (1)']
# [{'is_off': ['computer', '1']}, {'atreach': [['chair', '1'], ['keyboard', '1']]}, {'atreach': [['chair', '1'], ['computer', '1']]}, {'atreach': [['computer', '1'], ['chair', '1']]}, {'atreach': [['keyboard', '1'], ['chair', '1']]}, {'location': [['chair', '1'], ['home_office', '1']]}, {'location': [['computer', '1'], ['home_office', '1']]}, {'location': [['keyboard', '1'], ['home_office', '1']]}, {'free': ['chair', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <home_office> (197)
# True: <char0> [WALK] <chair> (244)
# True: <char0> [FIND] <chair> (244)
# True: <char0> [SIT] <chair> (244)
# True: <char0> [FIND] <computer> (273)
# True: <char0> [SWITCHON] <computer> (273)
# True: <char0> [TURNTO] <computer> (273)
# True: <char0> [LOOKAT] <computer> (273)
# True: <char0> [FIND] <keyboard> (275)
# True: <char0> [TYPE] <keyboard> (275)
# results_text_rebuttal_specialparsed_programs_turk_robot/split49_1.txt
# ['[Walk] <living_room> (1)', '[Walk] <couch> (1)', '[Find] <couch> (1)', '[Sit] <couch> (1)', '[Find] <paper> (1)', '[Grab] <paper> (1)', '[Drop] <paper> (1)']
# results_text_rebuttal_specialparsed_programs_turk_third/split44_4.txt
# ['[Walk] <home_office> (1)', '[Walk] <desk> (1)', '[Find] <chair> (1)', '[Sit] <chair> (1)', '[Find] <computer> (1)', '[SwitchOn] <computer> (1)', '[TurnTo] <computer> (1)', '[LookAt] <computer> (1)', '[Find] <notes> (1)', '[Grab] <notes> (1)', '[Read] <notes> (1)', '[Find] <keyboard> (1)', '[Type] <keyboard> (1)']
# [{'is_off': ['computer', '1']}, {'atreach': [['chair', '1'], ['notes', '1']]}, {'atreach': [['chair', '1'], ['keyboard', '1']]}, {'atreach': [['chair', '1'], ['computer', '1']]}, {'atreach': [['chair', '1'], ['desk', '1']]}, {'atreach': [['computer', '1'], ['desk', '1']]}, {'atreach': [['notes', '1'], ['desk', '1']]}, {'atreach': [['keyboard', '1'], ['desk', '1']]}, {'location': [['desk', '1'], ['home_office', '1']]}, {'location': [['chair', '1'], ['home_office', '1']]}, {'location': [['computer', '1'], ['home_office', '1']]}, {'location': [['notes', '1'], ['home_office', '1']]}, {'location': [['keyboard', '1'], ['home_office', '1']]}, {'free': ['chair', '1']}]
# switch off
# Script is executable
# name 'augmentation_utils' is not defined
# object_id_map
# {}
# True: <char0> [WALK] <home_office> (197)
# True: <char0> [WALK] <desk> (243)
# True: <char0> [FIND] <chair> (244)
# True: <char0> [SIT] <chair> (244)
# True: <char0> [FIND] <computer> (273)
# True: <char0> [SWITCHON] <computer> (273)
# True: <char0> [TURNTO] <computer> (273)
# True: <char0> [LOOKAT] <computer> (273)
# True: <char0> [FIND] <check> (1000)
# True: <char0> [GRAB] <check> (1000)
# True: <char0> [READ] <check> (1000)
# True: <char0> [FIND] <keyboard> (275)
# True: <char0> [TYPE] <keyboard> (275)

# %% [markdown]
# # 以下、ffmpegで動画生成

# %%
#complementing missing images
try:
    for activity_class in executable_activity_dic:
        executable_activity_list = executable_activity_dic[activity_class]
    #     for x in range(2):
        x = 0
        for activity in executable_activity_list:
            activity_name = activity["activity_name"]
            img_path = "../simulation/Output/scene" + str(scene) + "/" + activity_name + "0/0/??????_????_" + str(x) + "_normal.png"
            i = 0
            for file_path in sorted(glob.glob(img_path)):
                file_name = file_path.replace("../simulation/Output/scene" + str(scene) + "/" + activity_name + "0/0/", "")
                file_num = file_name.split("_")[1]
                if i != int(file_num):
                    print(str(i) + " " + str(int(file_num)))
                    for j in range(int(file_num)-i):
                        img = PIL.Image.open(file_path)
                        new_file_name = "../simulation/Output/scene" + str(scene) + "/" + activity_name + "0/0/" + "Action_%04d_" + str(x) + "_normal.png"
                        img.save(new_file_name % i)
                        print(file_name)
                        print(file_name + " - " + str(j+1))
# save
# 233 234
# Action_0234_0_normal.png
# Action_0234_0_normal.png - 1
# save
# 244 247
# Action_0247_0_normal.png
# Action_0247_0_normal.png - 1
# save
# Action_0247_0_normal.png
# Action_0247_0_normal.png - 2
# save
# Action_0247_0_normal.png
# Action_0247_0_normal.png - 3
# save

# %%
import subprocess

dir_path = "../simulation/Output/scene" + str(scene) + "/"
for activity_class in executable_activity_dic:
    executable_activity_list = executable_activity_dic[activity_class]
#     for x in range(2):
    x = 0
    for activity in executable_activity_list:
        try:
            activity_name = activity["activity_name"]
            if os.path.exists(dir_path + activity_name + "0"):
                print("success: " + activity_name)
                sh = subprocess.check_output(["ffmpeg", "-y", "-framerate", "14.5", "-i", dir_path + activity_name + "0/0/Action_%04d_" + str(x) + "_normal.png", "-vcodec", "libx264", "-pix_fmt", "yuv420p", "-r", "30", dir_path + activity_name + "0/0/" + activity_name.replace(" ", "_") + str(x) + ".mp4"])
                print(sh)
            else:
                print(activity_name)
        except Exception as e:
            print(e)
# Out:
# Take nap
# Sleep
# success: Go to sleep
# b''
# Put alarm clock in bedroom
# Have snack
# success: Get something to drink
# b''
# Eat cereal
# Drink
# success: Eat
# b''
# Eat cheese
# Eat snacks and drink tea
# Prepare pot of boiling water
# Fix snack
# Cook some food
# success: Cut bread
# b''
# Toast bread
# Make coffee
# Make popcorn
# Get ready for school
# Get ready to leave
# Arrange furniture
# Decorate it
# Put shoes in shoe rack
# Wash dishes by hand
# Light candles
# Put new books in shelves
# Sort laundry
# Unload various items from pockets and place them in bowl on table
# Wash dishes with dishwasher
# Place centerpiece
# Put away clean clothes
# Straighten paintings on wall
# Make bed
# Put away groceries
# success: Change toilet paper roll
# b''
# success: Turn off light
# b''
# Change sheets and pillow cases
# Set up buffet area
# Set up table
# Wash dishes
# Clean dishes
# Take dishes out of dishwasher
# Re arrange office
# Wash clothes
# Paint ceiling
# Clean toilet
# Clean sink
# Pick up cat hair
# success: Clean mirror
# b''
# De-wrinkle sheet
# Mop floor
# success: Oil dining room
# b''
# Organize closet
# Shred receipts
# Dust
# Vacuum
# Clean
# Sweep hallway please
# Wash sink
# Clean floor
# Clean room
# Put on coat
# Put on coat and shoes
# Apply lotion
# Check appearance in mirror
# Wash face
# Take off shoes
# Take shower
# Brush teeth
# Use toilet
# Deficate
# success: Put on your shoes
# b''
# Wash teeth
# Hand washing
# success: Go to toilet
# b''
# Take jacket off
# Change clothes
# Get dressed
# Wash hands
# Browse internet
# Read newspaper
# Relax
# Read book
# Read magazine
# Playing video game
# Listen to music
# Watch youtube
# Read news
# Play on laptop
# Social media  checks
# Watch movie
# Watch  horror  movie
# Play musical chairs
# Surf internet
# success: Play games
# b''
# Relax on sofa
# Shop
# Write book
# Grab things
# Turn light off
# Settle in
# Hang with friends
# Find dictionary
# Hang up car keys
# Compute
# Read
# Leave home
# Put umbrella away
# Turn on light
# Put away toys
# Getting  dresses
# Put down bags
# Look out window
# Look at mirror
# Use laptop
# Enjoy view out window
# Cutting
# Walk through
# Draft home
# success: Raise blinds
# b''
# Open window
# Hang up jacket
# Start computer
# Restock
# Wipe down counter
# Let baby learn how to walk
# success: Grab some juice
# b''
# Come home
# Open front door
# Pick up spare change on dresser
# Open door
# Put away shoes
# Enter home
# Spread table with appropriate supplies
# Switch on lamp
# Pick up toys
# Add paper to printer
# Pick up phone
# Receive credit card
# Throw away newspaper
# Feed me
# Open curtains
# Close door
# Put away jackets
# Put in chair
# Rain welcome
# Look at painting
# Dry soap bottles
# Entertain
# Text friends while sitting on couch
# success: Keep cats out of room
# b''
# Wake kids up
# success: Read to child
# b''
# Greet guests
# Pet cat
# Check email
# Use computer
# Research
# Print out document
# success: Surf web for money legitimate making opportunities
# b''
# Study
# Write report
# Complete surveys on amazon turk
# Type up document
# Write an email
# File documents
# success: Do homework
# b''
# success: Pay bills
# b''
# Homework
# Print out papers
# Browse internet
# Answer emails

# %% [markdown]
# # 以下、確認用

# %%
 len(executable_activity_list)
# Out:
# 25

# %%
executable_activity_list[0]
# Out:
# {'activity_name': 'Go to sleep',
#  'results': [{'file_name': 'results_intentions_march-13-18/file509_2.txt',
#    'name': 'Go to sleep',
#    'description': 'I walk into my bedroom. I change out of my clothing into pajamas. I turn off the light. I lie down in my bed and pull my sheets over me. I go to sleep.',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <clothes_pants> (1)',
#     '[Find] <clothes_pants> (1)',
#     '[Find] <clothes_pants> (1)',
#     '[Find] <clothes_pants> (1)',
#     '[PutOff] <clothes_pants> (1)',
#     '[Find] <clothes_shirt> (1)',
#     '[Find] <clothes_shirt> (1)',
#     '[Find] <clothes_shirt> (1)',
#     '[PutOff] <clothes_shirt> (1)',
#     '[Find] <clothes_shirt> (2)',
#     '[Grab] <clothes_shirt> (2)',
#     '[PutOn] <clothes_shirt> (2)',
#     '[Find] <clothes_pants> (2)',
#     '[Grab] <clothes_pants> (2)',
#     '[PutOn] <clothes_pants> (2)',
#     '[Find] <light> (1)',
#     '[SwitchOff] <light> (1)',
#     '[Find] <bed> (1)',
#     '[Lie] <bed> (1)',
#     '[Find] <sheets> (1)',
#     '[Pull] <sheets> (1)',
#     '[Sleep]']},
#   {'file_name': 'results_intentions_march-13-18/file1027_2.txt',
#    'name': 'Go to sleep',
#    'description': 'Walk to bedroom, walk to bed, lay down on bed, close eyes, go to sleep.',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <bed> (1)',
#     '[Lie] <bed> (1)',
#     '[Sleep]']},
#   {'file_name': 'results_intentions_march-13-18/file140_2.txt',
#    'name': 'Go to sleep',
#    'description': 'Walk in to bed room. lay down on bed.',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <bed> (1)',
#     '[Find] <bed> (1)',
#     '[TurnTo] <bed> (1)',
#     '[LookAt] <bed> (1)',
#     '[Sit] <bed> (1)',
#     '[Sleep]']},
#   {'file_name': 'results_intentions_march-13-18/file244_2.txt',
#    'name': 'Go to sleep',
#    'description': 'I walk to my room, walk to my bed, lie in my bed, and go to sleep.',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <bed> (1)',
#     '[Lie] <bed> (1)',
#     '[Sleep]']},
#   {'file_name': 'results_intentions_march-13-18/file181_1.txt',
#    'name': 'Go to sleep',
#    'description': 'go to bedroom, lie on Bed, sleep',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <bed> (1)',
#     '[Find] <bed> (1)',
#     '[Lie] <bed> (1)',
#     '[Sleep]']},
#   {'file_name': 'results_intentions_march-13-18/file736_1.txt',
#    'name': 'Go to sleep',
#    'description': 'Enter bedroom, turn on the light, and shut door. Change into night clothes. Turn off light. Turn down comforter, climb into bed, lay head on pillow, and cover up with comforter. Close eyes and drift off to sleep.',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <bed> (1)',
#     '[Find] <bed> (1)',
#     '[Lie] <bed> (1)',
#     '[Find] <comforter> (1)',
#     '[Pull] <comforter> (1)']},
#   {'file_name': 'results_intentions_march-13-18/file269_2.txt',
#    'name': 'Go to sleep',
#    'description': 'Walk to the bedroom.  Find the bed.  Lie down on the bed.  Close your eyes.  Wait.',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <bed> (1)',
#     '[Find] <bed> (1)',
#     '[Lie] <bed> (1)',
#     '[Sleep]']},
#   {'file_name': 'results_intentions_march-13-18/file875_1.txt',
#    'name': 'Go to sleep',
#    'description': 'walk to bedroom, look at the pillow, put pillow into bed, lie down in bed, sleep well',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <pillow> (1)',
#     '[Find] <pillow> (1)',
#     '[Grab] <pillow> (1)',
#     '[TurnTo] <pillow> (1)',
#     '[LookAt] <pillow> (1)',
#     '[Find] <bed> (1)',
#     '[PutBack] <pillow> (1) <bed> (1)',
#     '[Find] <bed> (1)',
#     '[Lie] <bed> (1)',
#     '[Sleep]']},
#   {'file_name': 'results_intentions_march-13-18/file274_1.txt',
#    'name': 'Go to sleep',
#    'description': 'Go to bedroom, undress and put on my pajama, put on the bed, set the clock alarm and switch off the lights.',
#    'list_of_steps': ['[Walk] <bedroom> (1)',
#     '[Walk] <clothes_dress> (1)',
#     '[Find] <clothes_dress> (1)',
#     '[Grab] <clothes_dress> (1)',
#     '[Drop] <clothes_dress> (1)',
#     '[Find] <clothes_underwear> (1)',
#     '[Grab] <clothes_underwear> (1)',
#     '[Drop] <clothes_underwear> (1)',
#     '[Find] <pajamas> (1)',
#     '[Grab] <pajamas> (1)',
#     '[PutOn] <pajamas> (1)',
#     '[Find] <bed> (1)',
#     '[Lie] <bed> (1)',
#     '[Find] <alarm_clock> (1)',
#     '[SwitchOn] <alarm_clock> (1)',
#     '[Find] <light> (1)',
#     '[SwitchOff] <light> (1)']}]}

# %%
cnt = 0
for executable_activity in rand_executable_activity_list:
    activity_list = executable_activity["results"]
    cnt += len(activity_list)
print(cnt)
# Out:
# 680
